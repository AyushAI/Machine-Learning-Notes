# %%
import pandas as pd

# %% [markdown]
# # Working with the JSON

# %%
pd.read_json('https://api.exchangerate-api.com/v4/latest/INR')
# Out:
#                              provider  \
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
# ANG  https://www.exchangerate-api.com
# ..                                ...
# XPF  https://www.exchangerate-api.com
# YER  https://www.exchangerate-api.com
# ZAR  https://www.exchangerate-api.com
# ZMW  https://www.exchangerate-api.com
# ZWL  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
# ANG  https://www.exchangerate-api.com/docs/free
# ..                                          ...
# XPF  https://www.exchangerate-api.com/docs/free
# YER  https://www.exchangerate-api.com/docs/free
# ZAR  https://www.exchangerate-api.com/docs/free
# ZMW  https://www.exchangerate-api.com/docs/free
# ZWL  https://www.exchangerate-api.com/docs/free
#
#                                       terms base       date  \
# AED  https://www.exchangerate-api.com/terms  INR 2023-08-11
# AFN  https://www.exchangerate-api.com/terms  INR 2023-08-11
# ALL  https://www.exchangerate-api.com/terms  INR 2023-08-11
# AMD  https://www.exchangerate-api.com/terms  INR 2023-08-11
# ANG  https://www.exchangerate-api.com/terms  INR 2023-08-11
# ..                                      ...  ...        ...
# XPF  https://www.exchangerate-api.com/terms  INR 2023-08-11
# YER  https://www.exchangerate-api.com/terms  INR 2023-08-11
# ZAR  https://www.exchangerate-api.com/terms  INR 2023-08-11
# ZMW  https://www.exchangerate-api.com/terms  INR 2023-08-11
# ZWL  https://www.exchangerate-api.com/terms  INR 2023-08-11
#
#      time_last_updated    rates
# AED         1691712001   0.0444
# AFN         1691712001   1.0200
# ALL         1691712001   1.1400
# AMD         1691712001   4.6600
# ANG         1691712001   0.0216
# ..                 ...      ...
# XPF         1691712001   1.3100
# YER         1691712001   3.0200
# ZAR         1691712001   0.2270
# ZMW         1691712001   0.2290
# ZWL         1691712001  56.5500
#
# [162 rows x 7 columns]

# %% [markdown]
# # SQL data

# %%
pip install mysql.connector
# Out:
# Requirement already satisfied: mysql.connector in c:\users\ayush\anaconda3\lib\site-packages (2.2.9)Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host="localhost",user="root",password="root",database="world",auth_plugin="mysql_native_password")

# %%
pd.read_sql_query("SELECT * FROM world.city WHERE CountryCode LIKE 'IND'",conn)
# Out:
# C:\Users\AYUSH\AppData\Local\Temp\ipykernel_2176\2435487095.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM world.city WHERE CountryCode LIKE 'IND'",conn)
#        ID                Name CountryCode        District  Population
# 0    1024     Mumbai (Bombay)         IND     Maharashtra    10500000
# 1    1025               Delhi         IND           Delhi     7206704
# 2    1026  Calcutta [Kolkata]         IND    West Bengali     4399819
# 3    1027    Chennai (Madras)         IND      Tamil Nadu     3841396
# 4    1028           Hyderabad         IND  Andhra Pradesh     2964638
# ..    ...                 ...         ...             ...         ...
# 336  1360        Ambala Sadar         IND         Haryana       90712
# 337  1361          Baidyabati         IND    West Bengali       90601
# 338  1362               Morvi         IND         Gujarat       90357
# 339  1363             Raigarh         IND     Chhatisgarh       89166
# 340  1364            Vejalpur         IND         Gujarat       89053
#
# [341 rows x 5 columns]

# %%
pd.read_sql_query("SELECT * FROM country",conn)
# Out:
# C:\Users\AYUSH\AppData\Local\Temp\ipykernel_2176\858535147.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM country",conn)
#     Code          Name      Continent                     Region  SurfaceArea  \
# 0    ABW         Aruba  North America                  Caribbean        193.0
# 1    AFG   Afghanistan           Asia  Southern and Central Asia     652090.0
# 2    AGO        Angola         Africa             Central Africa    1246700.0
# 3    AIA      Anguilla  North America                  Caribbean         96.0
# 4    ALB       Albania         Europe            Southern Europe      28748.0
# ..   ...           ...            ...                        ...          ...
# 234  YEM         Yemen           Asia                Middle East     527968.0
# 235  YUG    Yugoslavia         Europe            Southern Europe     102173.0
# 236  ZAF  South Africa         Africa            Southern Africa    1221037.0
# 237  ZMB        Zambia         Africa             Eastern Africa     752618.0
# 238  ZWE      Zimbabwe         Africa             Eastern Africa     390757.0
#
#      IndepYear  Population  LifeExpectancy       GNP    GNPOld  \
# 0          NaN      103000            78.4     828.0     793.0
# 1       1919.0    22720000            45.9    5976.0       NaN
# 2       1975.0    12878000            38.3    6648.0    7984.0
# 3          NaN        8000            76.1      63.2       NaN
# 4       1912.0     3401200            71.6    3205.0    2500.0
# ..         ...         ...             ...       ...       ...
# 234     1918.0    18112000            59.8    6041.0    5729.0
# 235     1918.0    10640000            72.4   17000.0       NaN
# 236     1910.0    40377000            51.1  116729.0  129092.0
# 237     1964.0     9169000            37.2    3377.0    3922.0
# 238     1980.0    11669000            37.8    5951.0    8670.0
#
#                  LocalName                                GovernmentForm  \
# 0                    Aruba  Nonmetropolitan Territory of The Netherlands
# 1    Afganistan/Afqanestan                               Islamic Emirate
# 2                   Angola                                      Republic
# 3                 Anguilla                 Dependent Territory of the UK
# 4               ShqipÃ«ria                                      Republic
# ..                     ...                                           ...
# 234               Al-Yaman                                      Republic
# 235            Jugoslavija                              Federal Republic
# 236           South Africa                                      Republic
# 237                 Zambia                                      Republic
# 238               Zimbabwe                                      Republic
#
#                   HeadOfState  Capital Code2
# 0                     Beatrix    129.0    AW
# 1               Mohammad Omar      1.0    AF
# 2    JosÃ© Eduardo dos Santos     56.0    AO
# 3                Elisabeth II     62.0    AI
# 4              Rexhep Mejdani     34.0    AL
# ..                        ...      ...   ...
# 234        Ali Abdallah Salih   1780.0    YE
# 235       Vojislav KoÂštunica   1792.0    YU
# 236               Thabo Mbeki    716.0    ZA
# 237         Frederick Chiluba   3162.0    ZM
# 238          Robert G. Mugabe   4068.0    ZW
#
# [239 rows x 15 columns]

# %%
df = pd.read_sql_query("SELECT * FROM countrylanguage",conn)
# Out:
# C:\Users\AYUSH\AppData\Local\Temp\ipykernel_2176\4272969784.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query("SELECT * FROM countrylanguage",conn)

# %%
df
# Out:
#     CountryCode    Language IsOfficial  Percentage
# 0           ABW       Dutch          T         5.3
# 1           ABW     English          F         9.5
# 2           ABW  Papiamento          F        76.7
# 3           ABW     Spanish          F         7.4
# 4           AFG     Balochi          F         0.9
# ..          ...         ...        ...         ...
# 979         ZMB      Tongan          F        11.0
# 980         ZWE     English          T         2.2
# 981         ZWE     Ndebele          F        16.2
# 982         ZWE      Nyanja          F         2.2
# 983         ZWE       Shona          F        72.1
#
# [984 rows x 4 columns]
